# %%
import pandas as pd
df = pd.read_csv("./data/datos_modificados.csv")

# %%
data = df

# %%
data.describe().round(1)
# Out:
#         Destination Port   Flow Duration   Total Fwd Packets  \
# count           691055.0        691055.0            691055.0
# mean              5685.6      28024783.3                 9.5
# std              15725.3      42766636.2               748.1
# min                 21.0             1.0                 1.0
# 25%                 53.0           202.0                 2.0
# 50%                 80.0         61540.0                 2.0
# 75%                443.0      83059271.0                 7.0
# max              65487.0     119999998.0            203943.0
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# count                 691055.0                     691055.0
# mean                      10.2                        556.4
# std                      985.4                       6170.9
# min                        0.0                          0.0
# 25%                        1.0                         12.0
# ...

# %%
data.shape

# %%
df.columns = df.columns.str.strip()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 691055 entries, 0 to 691054
# Data columns (total 68 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0    Destination Port             691055 non-null  int64
#  1    Flow Duration                691055 non-null  int64
#  2    Total Fwd Packets            691055 non-null  int64
#  3    Total Backward Packets       691055 non-null  int64
#  4   Total Length of Fwd Packets   691055 non-null  int64
#  5    Total Length of Bwd Packets  691055 non-null  int64
#  6    Fwd Packet Length Max        691055 non-null  int64
#  7    Fwd Packet Length Min        691055 non-null  int64
#  8    Fwd Packet Length Mean       691055 non-null  float64
#  9    Fwd Packet Length Std        691055 non-null  float64
#  10  Bwd Packet Length Max         691055 non-null  int64
#  11   Bwd Packet Length Min        691055 non-null  int64
# ...

# %%
data["Flow Duration"].value_counts().head(15)
# Out:
#  Flow Duration
# 3      28959
# 4      18716
# 1      12788
# 2       6056
# 5       3580
# 48      2459
# 49      2234
# 53      1072
# 191      988
# 52       982
# 6        974
# 54       958
# 50       954
# 192      936
# 47       914
# Name: count, dtype: int64

# %%
data["Flow Packets/s"].value_counts().head(15)
# Out:
#  Flow Packets/s
# 6.666667e+05    28677
# 5.000000e+05    17126
# 2.000000e+06    12726
# 1.000000e+06     5947
# 4.000000e+05     2348
# 4.166667e+04     2328
# 4.081633e+04     1862
# 7.500000e+05     1820
# 2.380952e+04     1093
# 2.409639e+04     1080
# 2.439024e+04     1049
# 2.564103e+04     1044
# 2.352941e+04     1029
# 2.272727e+04     1028
# 2.469136e+04     1027
# Name: count, dtype: int64

# %%
df['Flow Bytes/s'].value_counts().head(15)

# %%
df['Fwd Packet Length Mean'].value_counts().head(15)

# %%
df['Fwd Packet Length Mean'].describe()

# %%
df['Bwd Packet Length Mean'].value_counts().head(15)

# %%
df['Bwd Packet Length Mean'].describe()

# %%
df['Min Packet Length'].describe()

# %%
df['Max Packet Length'].describe()

# %%
data["Flow IAT Max"].value_counts().head(15)
# Out:
#  Flow IAT Max
# 3            30770
# 10000000     23562
# 4            18348
# 1            13391
# 100000000     9590
# 98300000      7215
# 10200000      6351
# 98700000      6223
# 2             5971
# 98400000      5534
# 98600000      5416
# 101000000     4746
# 99400000      4363
# 84900000      4172
# 84800000      4020
# Name: count, dtype: int64

# %%
data["Fwd IAT Max"].value_counts().head(15)
# Out:
#  Fwd IAT Max
# 0            104635
# 3             79779
# 4             43020
# 1             35114
# 10000000      14886
# 48            13804
# 10100000      11006
# 100000000      9588
# 2              9583
# 49             9275
# 98300000       7200
# 10200000       7045
# 98700000       6263
# 98400000       5546
# 98600000       5360
# Name: count, dtype: int64

# %%
data["Bwd IAT Max"].value_counts().head(15)
# Out:
#  Bwd IAT Max
# 0            262756
# 3             48343
# 4             33156
# 48            22914
# 10000000      15066
# 10100000      12706
# 1             11170
# 49            10447
# 10200000       6802
# 2              4706
# 100000000      3900
# 47             3872
# 59000000       3221
# 98700000       2341
# 98300000       2305
# Name: count, dtype: int64

# %%
data["Init_Win_bytes_forward"].value_counts().head(15)
# Out:
# Init_Win_bytes_forward
# -1        202922
#  251       92304
#  29200     76275
#  0         67270
#  274       64560
#  8192      52610
#  65535      6791
#  235        6546
#  256        5243
#  60         5033
#  229        4260
#  255        2243
#  253        2231
#  410        2041
#  349        1949
# Name: count, dtype: int64

# %%
data["Init_Win_bytes_backward"].value_counts().head(15)
# Out:
#  Init_Win_bytes_backward
# -1        334043
#  235      175355
#  0         15867
#  229        8273
#  60         8175
#  256        4195
#  29200      3732
#  31         3723
#  65535      3557
#  946        2549
#  939        2403
#  8          2397
#  360        2250
#  255        2215
#  28960      2209
# Name: count, dtype: int64

# %%
data["Active Max"].value_counts().head(15)
# Out:
#  Active Max
# 0       469195
# 5         6003
# 4         5893
# 6         2974
# 2         2642
# 3         2265
# 996       1077
# 995       1073
# 7         1073
# 997       1069
# 993       1062
# 1000      1019
# 998       1012
# 992       1008
# 994       1004
# Name: count, dtype: int64

# %%
data["Idle Max"].value_counts().head(15)
# Out:
#  Idle Max
# 0            461739
# 10000000      23455
# 100000000      9587
# 98300000       7215
# 10200000       6348
# 98700000       6223
# 98400000       5533
# 98600000       5416
# 101000000      4746
# 99400000       4363
# 84900000       4172
# 84800000       4020
# 85000000       3726
# 99300000       3509
# 98500000       3435
# Name: count, dtype: int64
